# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from numpy.random import seed
seed(1)
from tensorflow import random
random.set_seed(2)
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %%
dates = {'Week1':['Resources/sp500_mom_short.csv',
                              '2020-03-02',
                              '2020-03-07'
                             ],
         'Week2':['Resources/sp500_mom_short_wk2.csv',
                            '2020-03-09',
                             '2020-03-14'
                            ]}

# %%
in_sample=pd.DataFrame()
out_sample=pd.DataFrame()
out_sample_full=pd.DataFrame()

def LSTM_predictor(week):
    # Load the stock prices
    SP500_full = pd.read_csv(dates[week][0], index_col='date',infer_datetime_format=True, parse_dates=True)
    SP500_full.reset_index(inplace=True)
    SP500_full['date']=SP500_full['date'].dt.date
    SP500_full.index = pd.to_datetime(SP500_full['date'])
    SP500_full.drop(columns=['date'],inplace=True)
    
    #Trim the Dataframe to the relevant dates.
    df=SP500_full.loc[:dates[week][1]]
    
###############################################################################################  

    # This function accepts the column number for the features (X) and the target (y):
    # It chunks the data up with a rolling window of Xt-n to predict Xt
    # It returns a numpy array of X any y
    def window_data(df, window, feature_col_number, target_col_number):
        X = []
        y = []
        for i in range(len(df) - window):
            features = df.iloc[i:(i + window), feature_col_number]
            target = df.iloc[(i + window), target_col_number]
            X.append(features)
            y.append(target)
        return np.array(X), np.array(y).reshape(-1, 1)
   
    # Predict Closing Prices using a 10 day window of previous closing prices
    # Try a window size anywhere from 1 to 10 and see how the model performance changes
    #jjp - need to add a for loop 

    # Creating the features (X) and target (y) data using the window_data() function.
    window_size = 2

    # Column index 1 is the `Close` column
    feature_column = 5
    target_column = 5
    X, y = window_data(df, window_size, feature_column, target_column)    
    
################################################################################################ 

    # Use 70% of the data for training and the remaineder for testing
    split = int(0.7 *len(X))
    X_train_rnn = X[: split -1]
    X_test = X[split:]
    y_train_rnn = y[: split -1]
    y_test = y[split:]

    X_train_rnn, X_val_rnn, y_train_rnn, y_val_rnn = train_test_split(X_train_rnn, y_train_rnn)
    
################################################################################################ 

    # Use MinMaxScaler to scale the data between 0 and 1. 

    scaler = MinMaxScaler()
    scaler.fit(X)
    X_train_rnn =scaler.transform(X_train_rnn)
    X_val_rnn =scaler.transform(X_val_rnn)
    X_test = scaler.transform(X_test)
    scaler.fit(y)
    y_train_rnn = scaler.transform(y_train_rnn)
    y_val_rnn = scaler.transform(y_val_rnn)
    y_test =scaler.transform(y_test)

################################################################################################ 

    # Reshape the features for the model
    X_train_rnn = X_train_rnn.reshape((X_train_rnn.shape[0], X_train_rnn.shape[1], 1))
    X_val_rnn = X_val_rnn.reshape((X_val_rnn.shape[0], X_val_rnn.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
    
################################################################################################ 

    # BUILDING AND TRAINING THE LSTM RNN

    # Build the LSTM model. 
    # The return sequences need to be set to True if you are adding additional LSTM layers, but 
    # You don't have to do this for the final layer. 
    model = Sequential()

    number_units = 100
    dropout_fraction = 0.7

    #first layer:
    model.add(LSTM(
        units=number_units,
        return_sequences=True,
        input_shape=(X_train_rnn.shape[1], 1))
        )
    model.add(Dropout(dropout_fraction))
    #second layer
    model.add(LSTM(units=number_units, return_sequences=True))
    model.add(Dropout(dropout_fraction))
    #third layer
    model.add(LSTM(units=number_units, return_sequences=True))
    model.add(Dropout(dropout_fraction))
    # #fourth layer
    model.add(LSTM(units=number_units))
    model.add(Dropout(dropout_fraction))

    #output layer
    model.add(Dense(1))
    
    #Compile the model
    model.compile(optimizer="adam", loss="mean_squared_error")
    
################################################################################################ 

    # Train the model
    # Use at least 10 epochs
    # Do not shuffle the data
    # Experiement with the batch size, but a smaller batch size is recommended
    batch_size = 60
    epochs = 250
    model.fit(
        X_train_rnn,
        y_train_rnn,
        validation_data=(X_val_rnn, y_val_rnn),
        epochs=epochs,
        batch_size=batch_size,
        verbose=1
    )
    
################################################################################################

    #OUT OF SAMPLE PREDICTIONS
    seq = df[df.columns[feature_column]][-2:].tolist()
    forecast=[]
    for i in range (5):
        prediction = model.predict([np.array(seq).reshape(1,X_train_rnn.shape[1],1)])
        seq.append(prediction[0][0])
        seq.pop(0)
        forecast.append([prediction[0][0]])

    forecast_scaled=scaler.inverse_transform(forecast)
    fwd_prices=forecast_scaled.ravel()
    
    real_prices=SP500_full[SP500_full.columns[feature_column]][dates[week][1]:dates[week][2]].tolist()
    A=SP500_full.loc[dates[week][1]:dates[week][2]].index
    out_of_sample=pd.DataFrame({'Real_Prices':real_prices,
                          'Look_Fwd_Prices':fwd_prices},
                          index=A)
    
    look_fwd=pd.concat([SP500_full[SP500_full.columns[feature_column]][:dates[week][2]],out_of_sample],axis=1,join='outer')
    look_fwd_2020=look_fwd.iloc[-90:]

    
################################################################################################

    #IN SAMPLE PREDICTIONS
    predicted = model.predict(X_test)
    # Recover the original prices instead of the scaled version
    predicted_prices = scaler.inverse_transform(predicted)
    real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))
    #Create a dataframe of real and predicted values
    stock_closing = pd.DataFrame({
        "Real": real_prices.ravel(),
        "Predicted": predicted_prices.ravel()
    })
    
################################################################################################

#     #PLOT THE RESULTS
    
    #IN SAMPLE
    IN_SAMP=plt.figure()
    stock_closing.plot(title='Close price predictions using LSTM RNN on closing price',figsize=(20,10))
    IN_SAMP.savefig('Resources/in-sample-results_'+str(week)+ '.png')
    
    #OUT OF SAMPLE
    FWD_SMALL=plt.figure()
    out_of_sample.plot(figsize=(20,10), title='Real Price Data vs Look Fwd Prices (5 Days)')
    FWD_SMALL.savefig('Resources/out-samp-small-results_' +str(week)+ '.png')
    
    FWD = plt.figure()
    look_fwd_2020.plot(figsize=(20,10),title='Look Fwd Prices (5day) Against Actual')
    FWD.savefig('Resources/out-samp-full-results_' +str(week)+ '.png')   
    
                                      
    return IN_SAMP
    return FWD_SMALL
    return FWD

# %%
weeks = list(dates.keys())

# %%
for i in weeks:
    LSTM_predictor(i)
# Out:
# Train on 646 samples, validate on 216 samples
# Epoch 1/250
# 646/646 [==============================] - 5s 8ms/sample - loss: 0.2470 - val_loss: 0.1902
# Epoch 2/250
# 646/646 [==============================] - 0s 234us/sample - loss: 0.1020 - val_loss: 0.0296
# Epoch 3/250
# 646/646 [==============================] - 0s 199us/sample - loss: 0.0459 - val_loss: 0.0323
# Epoch 4/250
# 646/646 [==============================] - 0s 187us/sample - loss: 0.0378 - val_loss: 0.0300
# Epoch 5/250
# 646/646 [==============================] - 0s 186us/sample - loss: 0.0329 - val_loss: 0.0230
# Epoch 6/250
# 646/646 [==============================] - 0s 189us/sample - loss: 0.0308 - val_loss: 0.0207
# Epoch 7/250
# 646/646 [==============================] - 0s 186us/sample - loss: 0.0246 - val_loss: 0.0119
# Epoch 8/250
# 646/646 [==============================] - 0s 183us/sample - loss: 0.0242 - val_loss: 0.0065
# Epoch 9/250
# 646/646 [==============================] - 0s 185us/sample - loss: 0.0175 - val_loss: 0.0107
# Epoch 10/250
# 646/646 [==============================] - 0s 183us/sample - loss: 0.0176 - val_loss: 0.0014
# Epoch 11/250
# 646/646 [==============================] - 0s 207us/sample - loss: 0.0136 - val_loss: 0.0018
# Epoch 12/250
# 646/646 [==============================] - 0s 188us/sample - loss: 0.0146 - val_loss: 0.0036
# Epoch 13/250
# 646/646 [==============================] - 0s 186us/sample - loss: 0.0127 - val_loss: 0.0011
# Epoch 14/250
# 646/646 [==============================] - 0s 184us/sample - loss: 0.0121 - val_loss: 0.0010
# Epoch 15/250
# 646/646 [==============================] - 0s 184us/sample - loss: 0.0105 - val_loss: 0.0028
# Epoch 16/250
# 646/646 [==============================] - 0s 187us/sample - loss: 0.0117 - val_loss: 7.8496e-04
# Epoch 17/250
# 646/646 [==============================] - 0s 182us/sample - loss: 0.0106 - val_loss: 0.0022
# Epoch 18/250
# 646/646 [==============================] - 0s 184us/sample - loss: 0.0097 - val_loss: 9.5146e-04
# Epoch 19/250
# 646/646 [==============================] - 0s 187us/sample - loss: 0.0097 - val_loss: 0.0017
# Epoch 20/250
# 646/646 [==============================] - 0s 204us/sample - loss: 0.0094 - val_loss: 0.0016
# Epoch 21/250
# 646/646 [==============================] - 0s 187us/sample - loss: 0.0100 - val_loss: 9.6840e-04
# Epoch 22/250
# 646/646 [==============================] - 0s 185us/sample - loss: 0.0097 - val_loss: 9.2731e-04
# Epoch 23/250
# 646/646 [==============================] - 0s 185us/sample - loss: 0.0095 - val_loss: 8.0928e-04
# Epoch 24/250
# 646/646 [==============================] - 0s 187us/sample - loss: 0.0081 - val_loss: 8.5948e-04
# Epoch 25/250
# 646/646 [==============================] - 0s 187us/sample - loss: 0.0076 - val_loss: 0.0014
# Epoch 26/250
# 646/646 [==============================] - 0s 187us/sample - loss: 0.0084 - val_loss: 0.0012
# Epoch 27/250
# 646/646 [==============================] - 0s 188us/sample - loss: 0.0093 - val_loss: 8.6888e-04
# Epoch 28/250
# 646/646 [==============================] - 0s 202us/sample - loss: 0.0086 - val_loss: 8.4418e-04
# Epoch 29/250
# 646/646 [==============================] - 0s 191us/sample - loss: 0.0077 - val_loss: 0.0015
# Epoch 30/250
# 646/646 [==============================] - 0s 185us/sample - loss: 0.0086 - val_loss: 7.9658e-04
# Epoch 31/250
# 646/646 [==============================] - 0s 185us/sample - loss: 0.0086 - val_loss: 8.6812e-04
# Epoch 32/250
# 646/646 [==============================] - 0s 190us/sample - loss: 0.0080 - val_loss: 7.9088e-04
# Epoch 33/250
# 646/646 [==============================] - 0s 185us/sample - loss: 0.0086 - val_loss: 8.8172e-04
# Epoch 34/250
# 646/646 [==============================] - 0s 188us/sample - loss: 0.0084 - val_loss: 7.2775e-04
# Epoch 35/250
# 646/646 [==============================] - 0s 195us/sample - loss: 0.0077 - val_loss: 5.6352e-04
# Epoch 36/250
# 646/646 [==============================] - 0s 189us/sample - loss: 0.0076 - val_loss: 0.0016
# Epoch 37/250
# 646/646 [==============================] - 0s 208us/sample - loss: 0.0082 - val_loss: 0.0018
# Epoch 38/250
# 646/646 [==============================] - 0s 190us/sample - loss: 0.0076 - val_loss: 6.4017e-04
# Epoch 39/250
# 646/646 [==============================] - 0s 188us/sample - loss: 0.0080 - val_loss: 8.6444e-04
# Epoch 40/250
# 646/646 [==============================] - 0s 185us/sample - loss: 0.0081 - val_loss: 0.0012
# Epoch 41/250
# 646/646 [==============================] - 0s 189us/sample - loss: 0.0083 - val_loss: 0.0024
# Epoch 42/250
# 646/646 [==============================] - 0s 191us/sample - loss: 0.
250
# 649/649 [==============================] - 0s 214us/sample - loss: 0.0040 - val_loss: 8.0704e-04
# Epoch 54/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0034 - val_loss: 0.0011
# Epoch 55/250
# 649/649 [==============================] - 0s 213us/sample - loss: 0.0040 - val_loss: 7.6078e-04
# Epoch 56/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0040 - val_loss: 8.0322e-04
# Epoch 57/250
# 649/649 [==============================] - 0s 205us/sample - loss: 0.0039 - val_loss: 7.2921e-04
# Epoch 58/250
# 649/649 [==============================] - 0s 208us/sample - loss: 0.0036 - val_loss: 7.9615e-04
# Epoch 59/250
# 649/649 [==============================] - 0s 222us/sample - loss: 0.0037 - val_loss: 6.5716e-04
# Epoch 60/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0038 - val_loss: 9.4018e-04
# Epoch 61/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0035 - val_loss: 7.6901e-04
# Epoch 62/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0036 - val_loss: 8.4454e-04
# Epoch 63/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0032 - val_loss: 6.4583e-04
# Epoch 64/250
# 649/649 [==============================] - 0s 214us/sample - loss: 0.0041 - val_loss: 6.3157e-04
# Epoch 65/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0040 - val_loss: 8.5340e-04
# Epoch 66/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0039 - val_loss: 8.7142e-04
# Epoch 67/250
# 649/649 [==============================] - 0s 220us/sample - loss: 0.0038 - val_loss: 6.2278e-04
# Epoch 68/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0038 - val_loss: 0.0011
# Epoch 69/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0042 - val_loss: 7.1955e-04
# Epoch 70/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0033 - val_loss: 7.0905e-04
# Epoch 71/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0037 - val_loss: 9.5941e-04
# Epoch 72/250
# 649/649 [==============================] - 0s 214us/sample - loss: 0.0031 - val_loss: 8.6037e-04
# Epoch 73/250
# 649/649 [==============================] - 0s 200us/sample - loss: 0.0032 - val_loss: 8.0507e-04
# Epoch 74/250
# 649/649 [==============================] - 0s 218us/sample - loss: 0.0038 - val_loss: 8.0338e-04
# Epoch 75/250
# 649/649 [==============================] - 0s 217us/sample - loss: 0.0040 - val_loss: 7.2185e-04
# Epoch 76/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0036 - val_loss: 0.0012
# Epoch 77/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0035 - val_loss: 5.3321e-04
# Epoch 78/250
# 649/649 [==============================] - 0s 210us/sample - loss: 0.0035 - val_loss: 8.1561e-04
# Epoch 79/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0033 - val_loss: 5.8278e-04
# Epoch 80/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0033 - val_loss: 9.1765e-04
# Epoch 81/250
# 649/649 [==============================] - 0s 215us/sample - loss: 0.0033 - val_loss: 8.2075e-04
# Epoch 82/250
# 649/649 [==============================] - 0s 231us/sample - loss: 0.0035 - val_loss: 7.3798e-04
# Epoch 83/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0033 - val_loss: 7.0239e-04
# Epoch 84/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0034 - val_loss: 8.5310e-04
# Epoch 85/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0036 - val_loss: 6.8641e-04
# Epoch 86/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0032 - val_loss: 0.0012
# Epoch 87/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0037 - val_loss: 9.3481e-04
# Epoch 88/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0031 - val_loss: 5.5094e-04
# Epoch 89/250
# 649/649 [==============================] - 0s 212us/sample - loss: 0.0031 - val_loss: 6.6753e-04
# Epoch 90/250
# 649/649 [==============================] - 0s 220us/sample - loss: 0.0033 - val_loss: 0.0010
# Epoch 91/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0042 - val_loss: 6.0803e-04
# Epoch 92/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0034 - val_loss: 9.6548e-04
# Epoch 93/250
# 649/649 [==============================] - 0s 202us/sample - loss: 0.0033 - val_loss: 8.2454e-04
# Epoch 94/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.
250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0028 - val_loss: 8.2026e-04
# Epoch 178/250
# 649/649 [==============================] - 0s 214us/sample - loss: 0.0028 - val_loss: 6.1143e-04
# Epoch 179/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0022 - val_loss: 6.1370e-04
# Epoch 180/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0024 - val_loss: 6.0410e-04
# Epoch 181/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0024 - val_loss: 7.6612e-04
# Epoch 182/250
# 649/649 [==============================] - 0s 218us/sample - loss: 0.0025 - val_loss: 6.3613e-04
# Epoch 183/250
# 649/649 [==============================] - 0s 218us/sample - loss: 0.0023 - val_loss: 6.9558e-04
# Epoch 184/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0024 - val_loss: 6.9684e-04
# Epoch 185/250
# 649/649 [==============================] - 0s 205us/sample - loss: 0.0023 - val_loss: 6.2434e-04
# Epoch 186/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0024 - val_loss: 7.7071e-04
# Epoch 187/250
# 649/649 [==============================] - 0s 205us/sample - loss: 0.0026 - val_loss: 6.3584e-04
# Epoch 188/250
# 649/649 [==============================] - 0s 214us/sample - loss: 0.0024 - val_loss: 5.5298e-04
# Epoch 189/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0026 - val_loss: 0.0011
# Epoch 190/250
# 649/649 [==============================] - 0s 223us/sample - loss: 0.0023 - val_loss: 6.3962e-04
# Epoch 191/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0027 - val_loss: 8.4418e-04
# Epoch 192/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0026 - val_loss: 5.8060e-04
# Epoch 193/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0023 - val_loss: 7.4827e-04
# Epoch 194/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0022 - val_loss: 0.0012
# Epoch 195/250
# 649/649 [==============================] - 0s 202us/sample - loss: 0.0026 - val_loss: 7.2823e-04
# Epoch 196/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0028 - val_loss: 6.7333e-04
# Epoch 197/250
# 649/649 [==============================] - 0s 208us/sample - loss: 0.0022 - val_loss: 5.9734e-04
# Epoch 198/250
# 649/649 [==============================] - 0s 224us/sample - loss: 0.0026 - val_loss: 7.2820e-04
# Epoch 199/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0024 - val_loss: 6.8556e-04
# Epoch 200/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0024 - val_loss: 5.1343e-04
# Epoch 201/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0026 - val_loss: 5.9353e-04
# Epoch 202/250
# 649/649 [==============================] - 0s 208us/sample - loss: 0.0027 - val_loss: 9.5002e-04
# Epoch 203/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0031 - val_loss: 6.5470e-04
# Epoch 204/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0025 - val_loss: 7.2610e-04
# Epoch 205/250
# 649/649 [==============================] - 0s 214us/sample - loss: 0.0024 - val_loss: 6.2779e-04
# Epoch 206/250
# 649/649 [==============================] - 0s 218us/sample - loss: 0.0026 - val_loss: 9.6162e-04
# Epoch 207/250
# 649/649 [==============================] - 0s 200us/sample - loss: 0.0028 - val_loss: 7.4883e-04
# Epoch 208/250
# 649/649 [==============================] - 0s 208us/sample - loss: 0.0024 - val_loss: 8.7396e-04
# Epoch 209/250
# 649/649 [==============================] - 0s 213us/sample - loss: 0.0027 - val_loss: 6.2015e-04
# Epoch 210/250
# 649/649 [==============================] - 0s 208us/sample - loss: 0.0025 - val_loss: 6.9740e-04
# Epoch 211/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0024 - val_loss: 7.1113e-04
# Epoch 212/250
# 649/649 [==============================] - 0s 214us/sample - loss: 0.0022 - val_loss: 7.6492e-04
# Epoch 213/250
# 649/649 [==============================] - 0s 215us/sample - loss: 0.0026 - val_loss: 8.6325e-04
# Epoch 214/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0024 - val_loss: 7.2896e-04
# Epoch 215/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0024 - val_loss: 5.7098e-04
# Epoch 216/250
# 649/649 [==============================] - 0s 217us/sample - loss: 0.0022 - val_loss: 6.7233e-04
# Epoch 217/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0025 - val_loss: 6.0823e-04
# Epoch 218/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0022 - val_loss: 7.7727e-04
# Epoch 219/250
# 649/649 [==============================] - 0s 208us/sample - loss: 0.0024 - val_loss: 5.7053e-04
# Epoch 220/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0024 - val_loss: 6.5674e-04
# Epoch 221/250
# 649/649 [==============================] - 0s 241us/sample - loss: 0.0023 - val_loss: 7.5519e-04
# Epoch 222/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0025 - val_loss: 5.9939e-04
# Epoch 223/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0024 - val_loss: 8.1052e-04
# Epoch 224/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0023 - val_loss: 5.4380e-04
# Epoch 225/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0024 - val_loss: 9.4590e-04
# Epoch 226/250
# 649/649 [==============================] - 0s 205us/sample - loss: 0.0024 - val_loss: 5.4118e-04
# Epoch 227/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0024 - val_loss: 5.5660e-04
# Epoch 228/250
# 649/649 [==============================] - 0s 215us/sample - loss: 0.0023 - val_loss: 6.1945e-04
# Epoch 229/250
# 649/649 [==============================] - 0s 218us/sample - loss: 0.0024 - val_loss: 9.0913e-04
# Epoch 230/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0021 - val_loss: 5.4393e-04
# Epoch 231/250
# 649/649 [==============================] - 0s 212us/sample - loss: 0.0025 - val_loss: 6.9131e-04
# Epoch 232/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0020 - val_loss: 7.5505e-04
# Epoch 233/250
# 649/649 [==============================] - 0s 202us/sample - loss: 0.0025 - val_loss: 5.5307e-04
# Epoch 234/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0025 - val_loss: 7.6333e-04
# Epoch 235/250
# 649/649 [==============================] - 0s 213us/sample - loss: 0.0021 - val_loss: 6.1545e-04
# Epoch 236/250
# 649/649 [==============================] - 0s 218us/sample - loss: 0.0023 - val_loss: 6.7716e-04
# Epoch 237/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0023 - val_loss: 5.9759e-04
# Epoch 238/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0024 - val_loss: 8.8753e-04
# Epoch 239/250
# 649/649 [==============================] - 0s 210us/sample - loss: 0.0022 - val_loss: 5.6809e-04
# Epoch 240/250
# 649/649 [==============================] - 0s 212us/sample - loss: 0.0023 - val_loss: 7.2287e-04
# Epoch 241/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0022 - val_loss: 6.1006e-04
# Epoch 242/250
# 649/649 [==============================] - 0s 212us/sample - loss: 0.0023 - val_loss: 5.8891e-04
# Epoch 243/250
# 649/649 [==============================] - 0s 212us/sample - loss: 0.0024 - val_loss: 8.5227e-04
# Epoch 244/250
# 649/649 [==============================] - 0s 226us/sample - loss: 0.0025 - val_loss: 6.0804e-04
# Epoch 245/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0022 - val_loss: 8.3843e-04
# Epoch 246/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0023 - val_loss: 5.9072e-04
# Epoch 247/250
# 649/649 [==============================] - 0s 205us/sample - loss: 0.0023 - val_loss: 7.6660e-04
# Epoch 248/250
# 649/649 [==============================] - 0s 208us/sample - loss: 0.0022 - val_loss: 6.4722e-04
# Epoch 249/250
# 649/649 [==============================] - 0s 216us/sample - loss: 0.0023 - val_loss: 6.6938e-04
# Epoch 250/250
# 649/649 [==============================] - 0s 210us/sample - loss: 0.0023 - val_loss: 9.3714e-04

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---
