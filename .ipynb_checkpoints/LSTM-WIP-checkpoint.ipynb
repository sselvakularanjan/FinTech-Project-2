# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from numpy.random import seed
seed(1)
from tensorflow import random
random.set_seed(2)
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %%
dates = {'Week1':['Resources/sp500_mom_short.csv',
                              '2020-03-02',
                              '2020-03-07'
                             ],
         'Week2':['Resources/sp500_mom_short_wk2.csv',
                            '2020-03-09',
                             '2020-03-14'
                            ]}

# %%
def LSTM_predictor(week):
    # Load the stock prices
    SP500_full = pd.read_csv(dates[week][0], index_col='date',infer_datetime_format=True, parse_dates=True)
    SP500_full.reset_index(inplace=True)
    SP500_full['date']=SP500_full['date'].dt.date
    SP500_full.index = pd.to_datetime(SP500_full['date'])
    SP500_full.drop(columns=['date'],inplace=True)
    
    #Trim the Dataframe to the relevant dates.
    df=SP500_full.loc[:dates[week][1]]
    
###############################################################################################  

    # This function accepts the column number for the features (X) and the target (y):
    # It chunks the data up with a rolling window of Xt-n to predict Xt
    # It returns a numpy array of X any y
    def window_data(df, window, feature_col_number, target_col_number):
        X = []
        y = []
        for i in range(len(df) - window):
            features = df.iloc[i:(i + window), feature_col_number]
            target = df.iloc[(i + window), target_col_number]
            X.append(features)
            y.append(target)
        return np.array(X), np.array(y).reshape(-1, 1)
   
    # Predict Closing Prices using a 10 day window of previous closing prices
    # Try a window size anywhere from 1 to 10 and see how the model performance changes
    #jjp - need to add a for loop 

    # Creating the features (X) and target (y) data using the window_data() function.
    window_size = 2

    # Column index 1 is the `Close` column
    feature_column = 5
    target_column = 5
    X, y = window_data(df, window_size, feature_column, target_column)    
    
################################################################################################ 

    # Use 70% of the data for training and the remaineder for testing
    split = int(0.7 *len(X))
    X_train_rnn = X[: split -1]
    X_test = X[split:]
    y_train_rnn = y[: split -1]
    y_test = y[split:]

    X_train_rnn, X_val_rnn, y_train_rnn, y_val_rnn = train_test_split(X_train_rnn, y_train_rnn)
    
################################################################################################ 

    # Use MinMaxScaler to scale the data between 0 and 1. 

    scaler = MinMaxScaler()
    scaler.fit(X)
    X_train_rnn =scaler.transform(X_train_rnn)
    X_val_rnn =scaler.transform(X_val_rnn)
    X_test = scaler.transform(X_test)
    scaler.fit(y)
    y_train_rnn = scaler.transform(y_train_rnn)
    y_val_rnn = scaler.transform(y_val_rnn)
    y_test =scaler.transform(y_test)

################################################################################################ 

    # Reshape the features for the model
    X_train_rnn = X_train_rnn.reshape((X_train_rnn.shape[0], X_train_rnn.shape[1], 1))
    X_val_rnn = X_val_rnn.reshape((X_val_rnn.shape[0], X_val_rnn.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
    
################################################################################################ 

    # BUILDING AND TRAINING THE LSTM RNN

    # Build the LSTM model. 
    # The return sequences need to be set to True if you are adding additional LSTM layers, but 
    # You don't have to do this for the final layer. 
    model = Sequential()

    number_units = 100
    dropout_fraction = 0.7

    #first layer:
    model.add(LSTM(
        units=number_units,
        return_sequences=True,
        input_shape=(X_train_rnn.shape[1], 1))
        )
    model.add(Dropout(dropout_fraction))
    #second layer
    model.add(LSTM(units=number_units, return_sequences=True))
    model.add(Dropout(dropout_fraction))
    #third layer
    model.add(LSTM(units=number_units, return_sequences=True))
    model.add(Dropout(dropout_fraction))
    # #fourth layer
    model.add(LSTM(units=number_units))
    model.add(Dropout(dropout_fraction))

    #output layer
    model.add(Dense(1))
    
    #Compile the model
    model.compile(optimizer="adam", loss="mean_squared_error")
    
################################################################################################ 

    # Train the model
    # Use at least 10 epochs
    # Do not shuffle the data
    # Experiement with the batch size, but a smaller batch size is recommended
    batch_size = 60
    epochs = 250
    model.fit(
        X_train_rnn,
        y_train_rnn,
        validation_data=(X_val_rnn, y_val_rnn),
        epochs=epochs,
        batch_size=batch_size,
        verbose=1
    )
    
################################################################################################

    #OUT OF SAMPLE PREDICTIONS
    seq = df[df.columns[feature_column]][-2:].tolist()
    forecast=[]
    for i in range (5):
        prediction = model.predict([np.array(seq).reshape(1,X_train_rnn.shape[1],1)])
        seq.append(prediction[0][0])
        seq.pop(0)
        forecast.append([prediction[0][0]])

    forecast_scaled=scaler.inverse_transform(forecast)
    fwd_prices=forecast_scaled.ravel()
    
    real_prices=SP500_full[SP500_full.columns[feature_column]][dates[week][1]:dates[week][2]].tolist()
    A=SP500_full.loc[dates[week][1]:dates[week][2]].index
    out_of_sample=pd.DataFrame({'Real_Prices':real_prices,
                          'Look_Fwd_Prices':fwd_prices},
                          index=A)
    
    look_fwd=pd.concat([SP500_full[SP500_full.columns[feature_column]][:dates[week][2]],out_of_sample],axis=1,join='outer')
    look_fwd_2020=look_fwd.iloc[-90:]

    
################################################################################################

    #IN SAMPLE PREDICTIONS
    predicted = model.predict(X_test)
    # Recover the original prices instead of the scaled version
    predicted_prices = scaler.inverse_transform(predicted)
    real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))
    #Create a dataframe of real and predicted values
    stock_closing = pd.DataFrame({
        "Real": real_prices.ravel(),
        "Predicted": predicted_prices.ravel()
    })
    
################################################################################################

#     #PLOT THE RESULTS
    
    #IN SAMPLE
    IN_SAMP=plt.figure()
    stock_closing.plot(title='Close price predictions using LSTM RNN on closing price',figsize=(20,10))
    IN_SAMP.savefig('Resources/in-sample-results_'+str(week)+ '.png')
    
    #OUT OF SAMPLE
    FWD_SMALL=plt.figure()
    out_of_sample.plot(figsize=(20,10), title='Real Price Data vs Look Fwd Prices (5 Days)')
    FWD_SMALL.savefig('Resources/out-samp-small-results_' +str(week)+ '.png')
    
    FWD = plt.figure()
    look_fwd_2020.plot(figsize=(20,10),title='Look Fwd Prices (5day) Against Actual')
    FWD.savefig('Resources/out-samp-full-results_' +str(week)+ '.png')   
    
                                      
    return IN_SAMP
    return FWD_SMALL
    return FWD

# %%
weeks = list(dates.keys())

# %%
for i in weeks:
    LSTM_predictor(i)
# Out:
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Train on 646 samples, validate on 216 samples
# Epoch 1/250
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# 646/646 [==============================] - 5s 8ms/sample - loss: 0.2446 - val_loss: 0.1844
# Epoch 2/250
# 646/646 [==============================] - 0s 243us/sample - loss: 0.0979 - val_loss: 0.0254
# Epoch 3/250
# 646/646 [==============================] - 0s 206us/sample - loss: 0.0463 - val_loss: 0.0276
# Epoch 4/250
# 646/646 [==============================] - 0s 191us/sample - loss: 0.
250
# 649/649 [==============================] - 0s 203us/sample - loss: 0.0042 - val_loss: 6.0122e-04
# Epoch 41/250
# 649/649 [==============================] - 0s 223us/sample - loss: 0.0047 - val_loss: 9.1172e-04
# Epoch 42/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0042 - val_loss: 6.0995e-04
# Epoch 43/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0048 - val_loss: 6.7051e-04
# Epoch 44/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0043 - val_loss: 0.0011
# Epoch 45/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0039 - val_loss: 4.8305e-04
# Epoch 46/250
# 649/649 [==============================] - 0s 197us/sample - loss: 0.0048 - val_loss: 6.8007e-04
# Epoch 47/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0040 - val_loss: 8.4774e-04
# Epoch 48/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0039 - val_loss: 0.0013
# Epoch 49/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0042 - val_loss: 5.3630e-04
# Epoch 50/250
# 649/649 [==============================] - 0s 184us/sample - loss: 0.0038 - val_loss: 6.1849e-04
# Epoch 51/250
# 649/649 [==============================] - 0s 184us/sample - loss: 0.0039 - val_loss: 5.3498e-04
# Epoch 52/250
# 649/649 [==============================] - 0s 192us/sample - loss: 0.0038 - val_loss: 6.8578e-04
# Epoch 53/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0040 - val_loss: 6.8771e-04
# Epoch 54/250
# 649/649 [==============================] - 0s 195us/sample - loss: 0.0042 - val_loss: 6.5937e-04
# Epoch 55/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0043 - val_loss: 7.5798e-04
# Epoch 56/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0044 - val_loss: 6.2250e-04
# Epoch 57/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0041 - val_loss: 5.5639e-04
# Epoch 58/250
# 649/649 [==============================] - 0s 198us/sample - loss: 0.0036 - val_loss: 8.0380e-04
# Epoch 59/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0036 - val_loss: 6.1312e-04
# Epoch 60/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0038 - val_loss: 5.1661e-04
# Epoch 61/250
# 649/649 [==============================] - 0s 192us/sample - loss: 0.0038 - val_loss: 5.5306e-04
# Epoch 62/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0039 - val_loss: 6.2116e-04
# Epoch 63/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0034 - val_loss: 6.3021e-04
# Epoch 64/250
# 649/649 [==============================] - 0s 195us/sample - loss: 0.0036 - val_loss: 5.3581e-04
# Epoch 65/250
# 649/649 [==============================] - 0s 197us/sample - loss: 0.0039 - val_loss: 5.6016e-04
# Epoch 66/250
# 649/649 [==============================] - 0s 212us/sample - loss: 0.0046 - val_loss: 6.0706e-04
# Epoch 67/250
# 649/649 [==============================] - 0s 184us/sample - loss: 0.0036 - val_loss: 5.5895e-04
# Epoch 68/250
# 649/649 [==============================] - 0s 227us/sample - loss: 0.0034 - val_loss: 4.8055e-04
# Epoch 69/250
# 649/649 [==============================] - 0s 197us/sample - loss: 0.0040 - val_loss: 5.6895e-04
# Epoch 70/250
# 649/649 [==============================] - 0s 184us/sample - loss: 0.0037 - val_loss: 7.6384e-04
# Epoch 71/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0040 - val_loss: 4.8992e-04
# Epoch 72/250
# 649/649 [==============================] - 0s 194us/sample - loss: 0.0039 - val_loss: 0.0010
# Epoch 73/250
# 649/649 [==============================] - 0s 192us/sample - loss: 0.0034 - val_loss: 5.7103e-04
# Epoch 74/250
# 649/649 [==============================] - 0s 203us/sample - loss: 0.0034 - val_loss: 8.5794e-04
# Epoch 75/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0035 - val_loss: 4.6519e-04
# Epoch 76/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0038 - val_loss: 5.4718e-04
# Epoch 77/250
# 649/649 [==============================] - 0s 194us/sample - loss: 0.0032 - val_loss: 4.8211e-04
# Epoch 78/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0034 - val_loss: 5.2656e-04
# Epoch 79/250
# 649/649 [==============================] - 0s 192us/sample - loss: 0.0034 - val_loss: 7.8656e-04
# Epoch 80/250
# 649/649 [==============================] - 0s 195us/sample - loss: 0.0035 - val_loss: 4.9846e-04
# Epoch 81/250
# 649/649 [==============================] - 0s 224us/sample - loss: 0.0031 - val_loss: 5.9218e-04
# Epoch 82/250
# 649/649 [==============================] - 0s 298us/sample - loss: 0.0035 - val_loss: 5.2622e-04
# Epoch 83/250
# 649/649 [==============================] - 0s 301us/sample - loss: 0.0035 - val_loss: 5.0145e-04
# Epoch 84/250
# 649/649 [==============================] - 0s 283us/sample - loss: 0.0034 - val_loss: 4.9817e-04
# Epoch 85/250
# 649/649 [==============================] - 0s 254us/sample - loss: 0.0036 - val_loss: 8.1099e-04
# Epoch 86/250
# 649/649 [==============================] - 0s 263us/sample - loss: 0.0036 - val_loss: 0.0010
# Epoch 87/250
# 649/649 [==============================] - 0s 254us/sample - loss: 0.0037 - val_loss: 6.9805e-04
# Epoch 88/250
# 649/649 [==============================] - 0s 327us/sample - loss: 0.0032 - val_loss: 5.4426e-04
# Epoch 89/250
# 649/649 [==============================] - 0s 227us/sample - loss: 0.0033 - val_loss: 7.4746e-04
# Epoch 90/250
# 649/649 [==============================] - 0s 249us/sample - loss: 0.0033 - val_loss: 9.4882e-04
# Epoch 91/250
# 649/649 [==============================] - 0s 197us/sample - loss: 0.0040 - val_loss: 5.1688e-04
# Epoch 92/250
# 649/649 [==============================] - 0s 183us/sample - loss: 0.0034 - val_loss: 7.2107e-04
# Epoch 93/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0032 - val_loss: 7.3427e-04
# Epoch 94/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0036 - val_loss: 5.7518e-04
# Epoch 95/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0035 - val_loss: 0.0011
# Epoch 96/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0033 - val_loss: 5.5282e-04
# Epoch 97/250
# 649/649 [==============================] - 0s 177us/sample - loss: 0.0035 - val_loss: 6.3894e-04
# Epoch 98/250
# 649/649 [==============================] - 0s 198us/sample - loss: 0.0033 - val_loss: 5.6269e-04
# Epoch 99/250
# 649/649 [==============================] - 0s 220us/sample - loss: 0.0034 - val_loss: 5.9692e-04
# Epoch 100/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0033 - val_loss: 5.4566e-04
# Epoch 101/250
# 649/649 [==============================] - 0s 184us/sample - loss: 0.0033 - val_loss: 5.9063e-04
# Epoch 102/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0033 - val_loss: 5.8641e-04
# Epoch 103/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0030 - val_loss: 7.6734e-04
# Epoch 104/250
# 649/649 [==============================] - 0s 217us/sample - loss: 0.0031 - val_loss: 8.8808e-04
# Epoch 105/250
# 649/649 [==============================] - 0s 203us/sample - loss: 0.0030 - val_loss: 4.8632e-04
# Epoch 106/250
# 649/649 [==============================] - 0s 178us/sample - loss: 0.0030 - val_loss: 5.9283e-04
# Epoch 107/250
# 649/649 [==============================] - 0s 184us/sample - loss: 0.0033 - val_loss: 5.6569e-04
# Epoch 108/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0029 - val_loss: 5.0266e-04
# Epoch 109/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0034 - val_loss: 7.4188e-04
# Epoch 110/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0032 - val_loss: 5.8400e-04
# Epoch 111/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0031 - val_loss: 5.4398e-04
# Epoch 112/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0032 - val_loss: 5.7922e-04
# Epoch 113/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0031 - val_loss: 6.6996e-04
# Epoch 114/250
# 649/649 [==============================] - 0s 194us/sample - loss: 0.0031 - val_loss: 8.6024e-04
# Epoch 115/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0034 - val_loss: 8.1826e-04
# Epoch 116/250
# 649/649 [==============================] - 0s 228us/sample - loss: 0.0029 - val_loss: 6.4305e-04
# Epoch 117/250
# 649/649 [==============================] - 0s 195us/sample - loss: 0.0030 - val_loss: 5.0313e-04
# Epoch 118/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0027 - val_loss: 6.0804e-04
# Epoch 119/250
# 649/649 [==============================] - 0s 177us/sample - loss: 0.0030 - val_loss: 5.9159e-04
# Epoch 120/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0031 - val_loss: 4.6230e-04
# Epoch 121/250
# 649/649 [==============================] - 0s 211us/sample - loss: 0.0029 - val_loss: 7.8162e-04
# Epoch 122/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0032 - val_loss: 5.1460e-04
# Epoch 123/250
# 649/649 [==============================] - 0s 178us/sample - loss: 0.0027 - val_loss: 4.9313e-04
# Epoch 124/250
# 649/649 [==============================] - 0s 183us/sample - loss: 0.0031 - val_loss: 6.2179e-04
# Epoch 125/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0026 - val_loss: 5.5781e-04
# Epoch 126/250
# 649/649 [==============================] - 0s 205us/sample - loss: 0.0026 - val_loss: 6.6114e-04
# Epoch 127/250
# 649/649 [==============================] - 0s 200us/sample - loss: 0.0029 - val_loss: 4.9791e-04
# Epoch 128/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0030 - val_loss: 5.3090e-04
# Epoch 129/250
# 649/649 [==============================] - 0s 194us/sample - loss: 0.0029 - val_loss: 9.3381e-04
# Epoch 130/250
# 649/649 [==============================] - 0s 200us/sample - loss: 0.0030 - val_loss: 4.9122e-04
# Epoch 131/250
# 649/649 [==============================] - 0s 200us/sample - loss: 0.0027 - val_loss: 7.1398e-04
# Epoch 132/250
# 649/649 [==============================] - 0s 212us/sample - loss: 0.0028 - val_loss: 4.9177e-04
# Epoch 133/250
# 649/649 [==============================] - 0s 203us/sample - loss: 0.0029 - val_loss: 5.1973e-04
# Epoch 134/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0027 - val_loss: 8.6819e-04
# Epoch 135/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0031 - val_loss: 4.7980e-04
# Epoch 136/250
# 649/649 [==============================] - 0s 195us/sample - loss: 0.0027 - val_loss: 8.5353e-04
# Epoch 137/250
# 649/649 [==============================] - 0s 194us/sample - loss: 0.0027 - val_loss: 5.0375e-04
# Epoch 138/250
# 649/649 [==============================] - 0s 183us/sample - loss: 0.0029 - val_loss: 0.0010
# Epoch 139/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0030 - val_loss: 4.4733e-04
# Epoch 140/250
# 649/649 [==============================] - 0s 192us/sample - loss: 0.0029 - val_loss: 6.5058e-04
# Epoch 141/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0029 - val_loss: 7.5209e-04
# Epoch 142/250
# 649/649 [==============================] - 0s 200us/sample - loss: 0.0025 - val_loss: 5.0295e-04
# Epoch 143/250
# 649/649 [==============================] - 0s 194us/sample - loss: 0.0027 - val_loss: 4.9381e-04
# Epoch 144/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0026 - val_loss: 9.5795e-04
# Epoch 145/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0028 - val_loss: 4.9522e-04
# Epoch 146/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0028 - val_loss: 6.1246e-04
# Epoch 147/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0030 - val_loss: 6.2585e-04
# Epoch 148/250
# 649/649 [==============================] - 0s 200us/sample - loss: 0.0027 - val_loss: 4.7906e-04
# Epoch 149/250
# 649/649 [==============================] - 0s 221us/sample - loss: 0.0025 - val_loss: 5.5498e-04
# Epoch 150/250
# 649/649 [==============================] - 0s 212us/sample - loss: 0.0028 - val_loss: 5.9360e-04
# Epoch 151/250
# 649/649 [==============================] - 0s 195us/sample - loss: 0.0026 - val_loss: 4.8987e-04
# Epoch 152/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0026 - val_loss: 5.5877e-04
# Epoch 153/250
# 649/649 [==============================] - 0s 180us/sample - loss: 0.0026 - val_loss: 5.5769e-04
# Epoch 154/250
# 649/649 [==============================] - 0s 195us/sample - loss: 0.0027 - val_loss: 6.9790e-04
# Epoch 155/250
# 649/649 [==============================] - 0s 247us/sample - loss: 0.0027 - val_loss: 4.8616e-04
# Epoch 156/250
# 649/649 [==============================] - 0s 212us/sample - loss: 0.0026 - val_loss: 5.9203e-04
# Epoch 157/250
# 649/649 [==============================] - 0s 200us/sample - loss: 0.0026 - val_loss: 6.6660e-04
# Epoch 158/250
# 649/649 [==============================] - 0s 198us/sample - loss: 0.0028 - val_loss: 6.1508e-04
# Epoch 159/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0030 - val_loss: 7.9166e-04
# Epoch 160/250
# 649/649 [==============================] - 0s 181us/sample - loss: 0.0029 - val_loss: 5.4155e-04
# Epoch 161/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0026 - val_loss: 5.2933e-04
# Epoch 162/250
# 649/649 [==============================] - 0s 206us/sample - loss: 0.0024 - val_loss: 6.1157e-04
# Epoch 163/250
# 649/649 [==============================] - 0s 200us/sample - loss: 0.0028 - val_loss: 6.8892e-04
# Epoch 164/250
# 649/649 [==============================] - 0s 197us/sample - loss: 0.0027 - val_loss: 4.7158e-04
# Epoch 165/250
# 649/649 [==============================] - 0s 192us/sample - loss: 0.0023 - val_loss: 5.1299e-04
# Epoch 166/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0026 - val_loss: 4.2814e-04
# Epoch 167/250
# 649/649 [==============================] - 0s 183us/sample - loss: 0.0027 - val_loss: 6.5997e-04
# Epoch 168/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0026 - val_loss: 4.7702e-04
# Epoch 169/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0027 - val_loss: 5.7096e-04
# Epoch 170/250
# 649/649 [==============================] - 0s 195us/sample - loss: 0.0025 - val_loss: 4.8815e-04
# Epoch 171/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0022 - val_loss: 5.2669e-04
# Epoch 172/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0025 - val_loss: 4.7845e-04
# Epoch 173/250
# 649/649 [==============================] - 0s 226us/sample - loss: 0.0024 - val_loss: 5.9186e-04
# Epoch 174/250
# 649/649 [==============================] - 0s 215us/sample - loss: 0.0025 - val_loss: 4.4993e-04
# Epoch 175/250
# 649/649 [==============================] - 0s 184us/sample - loss: 0.0025 - val_loss: 7.3814e-04
# Epoch 176/250
# 649/649 [==============================] - 0s 183us/sample - loss: 0.0025 - val_loss: 4.5440e-04
# Epoch 177/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0025 - val_loss: 5.1962e-04
# Epoch 178/250
# 649/649 [==============================] - 0s 192us/sample - loss: 0.0027 - val_loss: 5.6926e-04
# Epoch 179/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0025 - val_loss: 6.0022e-04
# Epoch 180/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0026 - val_loss: 5.0941e-04
# Epoch 181/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0023 - val_loss: 5.0327e-04
# Epoch 182/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0028 - val_loss: 6.6559e-04
# Epoch 183/250
# 649/649 [==============================] - 0s 184us/sample - loss: 0.0025 - val_loss: 5.1523e-04
# Epoch 184/250
# 649/649 [==============================] - 0s 286us/sample - loss: 0.0023 - val_loss: 5.9007e-04
# Epoch 185/250
# 649/649 [==============================] - 0s 244us/sample - loss: 0.0022 - val_loss: 5.8382e-04
# Epoch 186/250
# 649/649 [==============================] - 0s 249us/sample - loss: 0.0024 - val_loss: 4.8489e-04
# Epoch 187/250
# 649/649 [==============================] - 0s 207us/sample - loss: 0.0024 - val_loss: 6.1125e-04
# Epoch 188/250
# 649/649 [==============================] - 0s 198us/sample - loss: 0.0026 - val_loss: 5.2628e-04
# Epoch 189/250
# 649/649 [==============================] - 0s 194us/sample - loss: 0.0024 - val_loss: 4.4434e-04
# Epoch 190/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0024 - val_loss: 7.0600e-04
# Epoch 191/250
# 649/649 [==============================] - 0s 194us/sample - loss: 0.0027 - val_loss: 5.3948e-04
# Epoch 192/250
# 649/649 [==============================] - 0s 192us/sample - loss: 0.0026 - val_loss: 5.9653e-04
# Epoch 193/250
# 649/649 [==============================] - 0s 198us/sample - loss: 0.0024 - val_loss: 5.0777e-04
# Epoch 194/250
# 649/649 [==============================] - 0s 223us/sample - loss: 0.0024 - val_loss: 5.6992e-04
# Epoch 195/250
# 649/649 [==============================] - 0s 209us/sample - loss: 0.0025 - val_loss: 4.5168e-04
# Epoch 196/250
# 649/649 [==============================] - 0s 195us/sample - loss: 0.0028 - val_loss: 7.2863e-04
# Epoch 197/250
# 649/649 [==============================] - 0s 195us/sample - loss: 0.0024 - val_loss: 5.3753e-04
# Epoch 198/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0025 - val_loss: 6.2785e-04
# Epoch 199/250
# 649/649 [==============================] - 0s 184us/sample - loss: 0.0025 - val_loss: 5.1454e-04
# Epoch 200/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0023 - val_loss: 4.6721e-04
# Epoch 201/250
# 649/649 [==============================] - 0s 192us/sample - loss: 0.0028 - val_loss: 5.5165e-04
# Epoch 202/250
# 649/649 [==============================] - 0s 192us/sample - loss: 0.0025 - val_loss: 9.5289e-04
# Epoch 203/250
# 649/649 [==============================] - 0s 204us/sample - loss: 0.0028 - val_loss: 5.5290e-04
# Epoch 204/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0027 - val_loss: 5.6905e-04
# Epoch 205/250
# 649/649 [==============================] - 0s 184us/sample - loss: 0.0025 - val_loss: 5.6203e-04
# Epoch 206/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0027 - val_loss: 6.5949e-04
# Epoch 207/250
# 649/649 [==============================] - 0s 194us/sample - loss: 0.0027 - val_loss: 5.9516e-04
# Epoch 208/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0026 - val_loss: 5.1513e-04
# Epoch 209/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0027 - val_loss: 5.2820e-04
# Epoch 210/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0025 - val_loss: 5.5878e-04
# Epoch 211/250
# 649/649 [==============================] - 0s 195us/sample - loss: 0.0023 - val_loss: 5.7063e-04
# Epoch 212/250
# 649/649 [==============================] - 0s 197us/sample - loss: 0.0026 - val_loss: 6.7494e-04
# Epoch 213/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0025 - val_loss: 5.4406e-04
# Epoch 214/250
# 649/649 [==============================] - 0s 184us/sample - loss: 0.0022 - val_loss: 5.9388e-04
# Epoch 215/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0023 - val_loss: 5.0672e-04
# Epoch 216/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0023 - val_loss: 5.2243e-04
# Epoch 217/250
# 649/649 [==============================] - 0s 194us/sample - loss: 0.0023 - val_loss: 5.0418e-04
# Epoch 218/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0023 - val_loss: 5.0368e-04
# Epoch 219/250
# 649/649 [==============================] - 0s 194us/sample - loss: 0.0023 - val_loss: 4.7120e-04
# Epoch 220/250
# 649/649 [==============================] - 0s 203us/sample - loss: 0.0021 - val_loss: 4.7158e-04
# Epoch 221/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0021 - val_loss: 5.8158e-04
# Epoch 222/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0024 - val_loss: 5.1909e-04
# Epoch 223/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0023 - val_loss: 5.1568e-04
# Epoch 224/250
# 649/649 [==============================] - 0s 184us/sample - loss: 0.0022 - val_loss: 5.6371e-04
# Epoch 225/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0025 - val_loss: 6.0205e-04
# Epoch 226/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0024 - val_loss: 4.2553e-04
# Epoch 227/250
# 649/649 [==============================] - 0s 181us/sample - loss: 0.0022 - val_loss: 7.3810e-04
# Epoch 228/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0025 - val_loss: 4.5204e-04
# Epoch 229/250
# 649/649 [==============================] - 0s 195us/sample - loss: 0.0028 - val_loss: 8.5569e-04
# Epoch 230/250
# 649/649 [==============================] - 0s 192us/sample - loss: 0.0025 - val_loss: 4.2838e-04
# Epoch 231/250
# 649/649 [==============================] - 0s 183us/sample - loss: 0.0026 - val_loss: 4.9655e-04
# Epoch 232/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0024 - val_loss: 6.3937e-04
# Epoch 233/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0024 - val_loss: 6.5289e-04
# Epoch 234/250
# 649/649 [==============================] - 0s 183us/sample - loss: 0.0022 - val_loss: 4.8103e-04
# Epoch 235/250
# 649/649 [==============================] - 0s 186us/sample - loss: 0.0023 - val_loss: 4.7552e-04
# Epoch 236/250
# 649/649 [==============================] - 0s 181us/sample - loss: 0.0025 - val_loss: 5.7732e-04
# Epoch 237/250
# 649/649 [==============================] - 0s 195us/sample - loss: 0.0021 - val_loss: 4.5982e-04
# Epoch 238/250
# 649/649 [==============================] - 0s 191us/sample - loss: 0.0023 - val_loss: 6.4847e-04
# Epoch 239/250
# 649/649 [==============================] - 0s 183us/sample - loss: 0.0024 - val_loss: 5.3043e-04
# Epoch 240/250
# 649/649 [==============================] - 0s 181us/sample - loss: 0.0024 - val_loss: 4.3705e-04
# Epoch 241/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0023 - val_loss: 8.6238e-04
# Epoch 242/250
# 649/649 [==============================] - 0s 194us/sample - loss: 0.0025 - val_loss: 4.5737e-04
# Epoch 243/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0024 - val_loss: 7.6348e-04
# Epoch 244/250
# 649/649 [==============================] - 0s 183us/sample - loss: 0.0023 - val_loss: 5.9462e-04
# Epoch 245/250
# 649/649 [==============================] - 0s 180us/sample - loss: 0.0023 - val_loss: 5.4247e-04
# Epoch 246/250
# 649/649 [==============================] - 0s 203us/sample - loss: 0.0022 - val_loss: 4.4868e-04
# Epoch 247/250
# 649/649 [==============================] - 0s 187us/sample - loss: 0.0022 - val_loss: 5.0887e-04
# Epoch 248/250
# 649/649 [==============================] - 0s 183us/sample - loss: 0.0024 - val_loss: 4.4302e-04
# Epoch 249/250
# 649/649 [==============================] - 0s 189us/sample - loss: 0.0025 - val_loss: 5.1083e-04
# Epoch 250/250
# 649/649 [==============================] - 0s 194us/sample - loss: 0.0025 - val_loss: 4.9203e-04

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---
