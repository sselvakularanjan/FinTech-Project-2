# %%
# pip install tiingo

# %%
import pandas as pd
import numpy as np
import os as os
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import tiingo
from tiingo import TiingoClient
from pathlib import Path
from datetime import date
import json
import os
from iexfinance.stocks import get_historical_data
from iexfinance.refdata import get_symbols

# %%
#this is an output download from
sp500_csv = pd.read_csv('../Fintech-Project-2/sp500_close.csv')
sp500_csv.head()
# Out:
#                         date     MMM    ABT   ABBV    ABMD     ACN   ATVI  \
# 0  2019-03-01 00:00:00+00:00  207.49  78.59  80.10  348.06  164.20  42.84
# 1  2019-03-04 00:00:00+00:00  206.86  78.62  79.46  338.20  162.82  41.79
# 2  2019-03-05 00:00:00+00:00  203.84  78.22  78.91  333.21  163.67  41.88
# 3  2019-03-06 00:00:00+00:00  202.80  77.70  78.09  317.85  162.39  42.56
# 4  2019-03-07 00:00:00+00:00  199.86  76.80  78.24  317.42  161.85  41.42
#
#      ADBE    AMD     AAP  ...    WLTW    WYNN    XEL    XRX    XLNX    XYL  \
# 0  264.01  23.68  160.62  ...  172.56  125.12  54.92  31.29  126.64  76.37
# 1  258.16  23.37  158.40  ...  173.05  125.57  55.08  31.36  122.81  76.25
# 2  257.38  23.50  157.31  ...  182.04  124.14  54.90  31.09  122.95  76.19
# 3  256.40  22.41  157.97  ...  170.88  123.55  55.09  30.85  121.36  75.85
# 4  255.46  22.08  154.13  ...  170.20  118.67  55.52  30.24  119.91  75.32
#
#      YUM     ZBH   ZION    ZTS
# 0  95.37  125.41  51.17  95.75
# ...

# %%
sp500=sp500_csv.columns.to_list()
sp500_tickers=sp500[1:]
# sp500_tickers

# %%
# Set the file path
tiingo = os.getenv('TIINGO_API_KEY')

# %%
client = TiingoClient()

# %% [markdown]
# ## Get data
# The first thing we need to do in order to build our trade is to get the data. One method is to go to Quandl and pay for an API, but in true "hack3r" form, why pay for data when you can take a few steps to extract it for free?
#
# Therefore, let's go get our investing universe, the S&P 500 and go about the process of building a data frame.

# %%
end_date = datetime.now()
start_date = end_date + timedelta(-365*5)

# %%
sp500_df = client.get_dataframe(sp500,
                                metric_name='close',
                                startDate=start_date,
                                endDate=end_date,
                                frequency='daily'
                               )
# Out:
# C:\Users\mrich\AppData\Local\Continuum\anaconda3\lib\site-packages\tiingo\api.py:270: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   prices = pd.concat([prices, df[stock]], axis=1)

# %%
sp500_df.describe()
# Out:
#              date          MMM         ABT         ABBV         ABMD  \
# count  282.000000  1259.000000  1259.00000  1259.000000  1259.000000
# mean     6.809234   183.768102    57.91089    75.889595   188.381044
# std      0.664318    26.453584    16.12584    15.516180   103.175083
# min      5.100000   117.870000    36.34000    48.270000    59.660000
# 25%      6.340000   163.840000    43.80500    63.185000   104.975000
# 50%      6.930000   178.360000    53.68000    71.240000   154.260000
# 75%      7.380000   204.420000    71.52000    88.925000   265.250000
# max      9.280000   258.630000    91.86000   123.210000   449.750000
#
#                ACN         ATVI         ADBE          AMD          AAP  ...  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000  ...
# mean    141.295989    49.895536   180.753729    15.719619   146.629380  ...
# std      33.054298    14.910589    85.284995    12.772118    24.971834  ...
# ...

# %%
path='../FinTech-Project-2/'

# %%
sp500_df.to_csv(path+'MSR_sp500_5yr_close.csv')
